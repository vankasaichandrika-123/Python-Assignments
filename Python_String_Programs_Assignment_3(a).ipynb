# %% [markdown]
# **PYTHON STRING ASSIGNMENT**
#
# **Part-A**
#
#
#
# 1.b(Immutable)
# 2.b(Memory location)
# 3.b(New memory is allocated)
# 4.a(0)
# 5.a(-5)
# 6.c(t)
# 7.b(o)
# 8.b(ell)
# 9.a(pyt)
# 10.b(thon)
# 11.b(Reversing string)
# 12.a(ace)
# 13.a[3:6]
# 14.a(Characters count)
# 15.b(All uppercase string)
# 16.a(Uppercase→Lowercase)
# 17.a( strip())
# 18.a(Python)
# 19.b(false)
# 20.a( Contains digits only)
# 21.a(Only letters)
# 22.a( find())
# 23.a(find() returns −1, index() raises error)
# 24.a(hexxo)
# 25.b(1)
# 26.b( space)
# 27.b(a.b.c)
# 28.c(HelloHello)
# 29.a(True)
# 30.a(True)

# %% [markdown]
# **Part - B**
# #Take a string from user and print its length.

# %%
s="Python"
print(len(s))
# Out:
# 6

# %%
#Input a string and print first and last character.
s="PythonDeveloper"
print(s)
print("First:", s[0])
print("last:",s[-1])
# Out:
# PythonDeveloper
# First: P
# last: r

# %%
#Input a string and print character at index 2 and −2.
a="JavaDeveloper"
print(a)
print(a[2])
print(a[-2])
# Out:
# JavaDeveloper
# v
# e

# %%
#Input a string and print the middle character(s).
b="Data Science"
print(b)
print(b[-1])

# %%
#Reverse a string using slicing.
c="Data Analystics"
print(c)
print(c[::-1])
# Out:
# Data Analystics
# scitsylanA ataD

# %%
#Extract first 5 characters and last 5 characters.
d="Machine Learning"
print(d)
print(d[:5])
print(d[:-5])
# Out:
# Machine Learning
# Machi
# Machine Lea

# %%
#Print every second character from a string.
D="Contraction"
print(D)
print(D[::2])
# Out:
# Contraction
# Cnrcin

# %%
#Print characters from 2nd index to 7th index.
j="Software Developer"
print(j)
print(j[2:8])
# Out:
# Software Developer
# ftware

# %%
#Remove leading and trailing spaces from input string.
S="Bussiness Analaysis"
print(S.split())
# Out:
# ['Bussiness', 'Analaysis']

# %%
#Convert string to uppercase and lowercase.
H="Digilocker"
print(H)
print(H.upper())
print(H.lower())
# Out:
# Digilocker
# DIGILOCKER
# digilocker

# %%
#Replace all spaces in a string with -.
K="Python"
print(s.replace("" ,"-"))
# Out:
# -P-y-t-h-o-n-D-e-v-e-l-o-p-e-r-

# %%
#Check if a string starts with "A" or ends with "Z".
M="Saikamal Sir"
print(M.startswith('A'))
print(M.endswith('Z'))
# Out:
# False
# False

# %%
#Count occurrences of a character in string using count().

N=input("Saichandrika")
O=input("Saranya")
print(N.count(O))
# Out:
# Saichandrika3
# Saranya2
# 0

# %%
#Find position of substring in given string.
l="Kamal Sir"
l1="Satish"
print(l.find(l1))
# Out:
# -1

# %%
#Split a string into words and print each word separately (no loop — use index access methods).
P=input( "SpringBoot")
words=P.split()

print(words[0])
print(words[1])
print(words[2])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2264/2957389201.py in <cell line: 0>()
#       1 #Split a string into words and print each word separately (no loop — use index access methods).
# ----> 2 P=input( "SpringBoot")
#       3 words=P.split()
#       4
#       5 print(words[0])
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
#Check if input is numeric or alphabetic.
t="Saichandrika123"
print(t)
print(t.isdigit())
print(t.isalpha())
print(t.isalnum())

# %%
#Swap first and last characters of string using slicing.
s=input("Deep Learning")
print(s[-1] + s[1:-1] + s[0])

# %%
#Check if two strings are equal (case-insensitive).
S="Java Developer"
S1="Python Developer"

print(S.lower() == S1.lower())

# %%
#Create a substring by skipping characters: s[1:len(s):2].

s = input("Microservice ")
print(s[1:len(s):2])

# %%
#Join a list of strings into one string separated by commas.
lst = ["apple", "banana", "orange"]
result = ",".join(lst)
print(result)
